# %%
import tensorflow as tf
# Out:
# /anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
import matplotlib.image as img
import matplotlib.pyplot as plt

# %%
imgfile = "./cat.jpg"

# %%
image = img.imread(imgfile)

# %%
print ("Image shape: ", image.shape)
# Out:
# Image shape:  (414, 500, 3)

# %%
print ("Image array: ", image)
# Out:
# Image array:  [[[160 151 142]
#   [164 155 146]
#   [169 160 151]
#   ...
#   [185 172 156]
#   [184 171 155]
#   [183 170 154]]
#
#  [[126 118 107]
#   [131 123 112]
#   [136 128 117]
#   ...
#   [184 171 155]
#   [183 170 154]
#   [182 169 153]]
#
#  [[127 119 108]
#   [131 123 112]
#   [137 129 118]
#   ...
#   [183 170 154]
#   [182 169 153]
#   [181 168 152]]
#
#  ...
#
#  [[198 186 162]
#   [193 181 157]
#   [178 166 142]
#   ...
#   [206 204 181]
#   [195 193 170]
#   [174 172 149]]
#
#  [[176 164 140]
#   [183 171 147]
#   [175 163 139]
#   ...
#   [188 187 167]
#   [144 143 123]
#   [125 124 104]]
#
#  [[190 178 154]
#   [190 178 154]
#   [157 145 121]
#   ...
#   [200 198 185]
#   [145 143 130]
#   [144 142 129]]]

# %%
plt.imshow(image)
plt.show()

# %%
x = tf.Variable(image, name='x')

# %%
init = tf.global_variables_initializer()

# %%
with tf.Session() as sess:
    sess.run(init)

    transpose = tf.image.transpose_image(x)

    result = sess.run(transpose)

    print ("Transposed image shape: ", result.shape)
    plt.imshow(result)
    plt.show()
# Out:
# Transposed image shape:  (500, 414, 3)
